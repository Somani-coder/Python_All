# %%
#IF STATEMENT

# %%
Tomato = 15
if Tomato <=10:
    print("Bring 1kg of tomatoes")

# %%
Tomato = 15
if Tomato <=20:
    print("Bring 1kg of tomatoes")
# Out:
# Bring 1kg of tomatoes

# %%
a = 33
b = 200
if b > a:      # : declaration
    print("b is greater than a")
# Out:
# b is greater than a

# %%
x=9
if x<10:
  print("Data Science")
# Out:
# Data Science

# %%
if True:
  print("Data Science")
# Out:
# Data Science

# %%
if 0:
  print("Data Science")

# %%
if 1:
  print("Data Science")
# Out:
# Data Science

# %%
x=9
if x%2==1:
  print("Data Science")
# Out:
# Data Science

# %%
x=13
if x//2==6:
  print("Data Science")
# Out:
# Data Science

# %%
x=int(input())
if (not(x%2==0) and (x<10)):
  print("Data Science")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 x=int(input())
#       2 if (not(x%2==0) and (x<10)):
#       3   print("Data Science")
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
y=int(input())
if not(y<10):
  print("Y is not less than 10")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 y=int(input())
#       2 if not(y<10):
#       3   print("Y is not less than 10")
#
# ValueError: invalid literal for int() with base 10: 'ESCAPE'

# %%
#IF-ELSE STATEMENT

# %%
x = 3
if x >5:
  print("X is gretaer than 5")
else:
  print("X is maller than 5")
# Out:
# X is maller than 5

# %%
Tomato =int(input("Tomatoes Cost Per Kg:\n"))
if Tomato <40:
    print("Bring 5 Kg of tomatoes")
elif Tomato <= 50:
    print("Bring 2 kgs of tomatoes ")

else:
    print("Bring 1/2 Kg of tomatoes")
# Out:
# Bring 1/2 Kg of tomatoes
